# %%
# %run imports.py
# Out:
# Succesfully imported libraries and modules

# %%
N = 8000
fs = 2000
timepoints = np.arange(N) / fs
x = generate_coupled_signal(10, 250, 1, 1/6, 0.01, timepoints, 1)

# %%
cut = 1/4
cut = int(cut * fs)
plt.figure(figsize=(8, 4))
plt.plot(timepoints[:cut], x[:cut], color='black')
plt.grid(linestyle='--')
plt.xlabel("Время, с")
plt.ylabel("Амлитуда, мкВ")

sns.set(context='poster', style='ticks', palette='bright', font='sans-serif', font_scale=1, color_codes=True, rc=None)

# %%
# %matplotlib widget

plt.plot(timepoints, np.sin(5 * timepoints))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
